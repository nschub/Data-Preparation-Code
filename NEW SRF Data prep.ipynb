# %%
import pandas as pd
import numpy as np
import re
from IPython.display import display

# %%
# import srf cs data

file_paths = [
    "Data/SRF/scraped_data_CS_april.csv",
    "Data/SRF/scraped_data_1000_credit_suisse.csv"
]

# List to store DataFrames
dfs = []

# Read each CSV file into a DataFrame and append to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_srf_cs = pd.concat(dfs, ignore_index=True)

# %%
# import SRF CS data
#file_path = "Data/SRF/scraped_data_CS_april.csv"
#df_srf_cs = pd.read_csv(file_path)

# %%
df_srf_cs.head()
# Out:
#                                        article_title  \
# 0                   Ex-CS-Chefs dürfen Boni behalten
# 1  Finma will mehr Kompetenzen – und höhere Anfor...
# 2  CS-Krise hatte Einfluss auf die Wahlen und das...
# 3  Credit Suisse und Kantonalbanken: Wer profitie...
# 4        Das Quiz zur Übernahme der CS durch die UBS
#
#                                        merged_string  \
# 0  Die ehemaligen Führungskräfte der untergegange...
# 1  Die Finanzmarktaufsicht Finma fordert stärkere...
# 2  Finanzministerin Karin Keller-Sutter wurde von...
# 3  Profitieren die Kantonalbanken vom CS-Aus? Gem...
# 4  Der 19. März 2023 wurde zum Schicksalstag für ...
#
#                    text_date
# 0  2024-04-14T10:35:00+02:00
# 1  2024-03-20T09:32:00+01:00
# 2  2024-03-19T18:53:00+01:00
# 3  2024-03-19T05:44:00+01:00
# 4  2024-03-18T14:53:00+01:00

# %%
len(df_srf_cs)
# Out:
# 1959

# %%
#df_srf_cs.to_csv('SRF URLS/df_srf_cs_merged.csv', index=False)

# %%
# Out:
# 799

# %% [markdown]
# #### remove dups

# %%
# Check for duplicates in the merged DataFrame, keeping all occurrences
all_occurrences_indices = df_srf_cs[df_srf_cs.duplicated(keep=False)].index

# Display the indices of all occurrences of duplicate rows
print("Indices of All Occurrences of Duplicate Rows:")
print(all_occurrences_indices)
# Out:
# Indices of All Occurrences of Duplicate Rows:
# Index([ 366,  393,  444,  914, 1152, 1153, 1154, 1155, 1241, 1245, 1269, 1270,
#        1316, 1472, 1473, 1563, 1672, 1709, 1837, 1904, 1906, 1907],
#       dtype='int64')

# %%
duplicate_indices_specific_columns = df_srf_cs[df_srf_cs.duplicated(subset=['article_title'], keep=False)].index
print("Indices of Duplicate Rows Based on Specific Columns:")
print(duplicate_indices_specific_columns)
# Out:
# Indices of Duplicate Rows Based on Specific Columns:
# Index([  37,   40,   44,   45,   46,   50,   52,   53,   54,   55,
#        ...
#        1912, 1915, 1919, 1920, 1922, 1929, 1938, 1943, 1951, 1954],
#       dtype='int64', length=889)

# %%
# Remove duplicate rows based on specific columns --> No duplicates found
df_srf_cs_no_dups = df_srf_cs.drop_duplicates(subset=['article_title'], keep='first')

# %%
df_srf_cs = df_srf_cs_no_dups

# %% [markdown]
# #### filter by time

# %%
# Convert 'text_date' column to datetime type, considering timezone information
df_srf_cs['text_date'] = pd.to_datetime(df_srf_cs['text_date'], utc=True)

# Define the start and end dates of the desired range
start_date = pd.Timestamp('2019-01-01', tz='UTC')
end_date = pd.Timestamp('2023-06-30', tz='UTC')

# Filter the DataFrame to include only articles within the specified date range
filtered_df_srf_cs = df_srf_cs[(df_srf_cs['text_date'] >= start_date) & (df_srf_cs['text_date'] <= end_date)]

# %%
len(filtered_df_srf_cs)
# Out:
# 544

# %% [markdown]
# #### filter by relevancy

# %%
filtered_df_srf_cs_copy = filtered_df_srf_cs.copy()

# Create a boolean Series where each element is True if the corresponding article contains 'credit suisse' or 'CREDIT SUISSE'

contains_lower = filtered_df_srf_cs_copy['merged_string'].str.contains('CREDIT SUISSE', case=True)
contains_upper = filtered_df_srf_cs_copy['merged_string'].str.contains('Credit suisse', case=True)

# Combine the two Series using the bitwise OR operator

contains_either = contains_lower | contains_upper

# Check if any articles contain 'credit suisse' or 'CREDIT SUISSE'

any_contains_either = contains_either.any()

print(f"Any articles contain 'credit suisse' or 'CREDIT SUISSE'? {any_contains_either}")

num_contains_either = contains_either.sum()

print(f"Number of articles that contain 'credit suisse' or 'CREDIT SUISSE': {num_contains_either}")
# Out:
# Any articles contain 'credit suisse' or 'CREDIT SUISSE'? False
# Number of articles that contain 'credit suisse' or 'CREDIT SUISSE': 0

# %%
# Create a copy of the filtered DataFrame
filtered_df_srf_cs_copy = filtered_df_srf_cs.copy()

# Count the occurrences of the phrases 'Credit Suisse' and 'CS' in each article's content in the copied DataFrame
def count_credit_suisse(text):
    return len(re.findall(r'credit[-\s]*suisse', text, re.IGNORECASE))
    
filtered_df_srf_cs_copy['credit_suisse_count'] = filtered_df_srf_cs_copy['merged_string'].apply(count_credit_suisse)

def count_cs(text):
    return len(re.findall(r'(?<![a-zA-Z])CS(?![a-zA-Z])', text))

filtered_df_srf_cs_copy['cs_count'] = filtered_df_srf_cs_copy['merged_string'].apply(count_cs)

# Filter articles based on multiple conditions
credit_suisse_articles = filtered_df_srf_cs_copy[
    (filtered_df_srf_cs_copy['credit_suisse_count'] >= 2) |
    (filtered_df_srf_cs_copy['cs_count'] >= 2) |
    ((filtered_df_srf_cs_copy['credit_suisse_count'] >= 1) & (filtered_df_srf_cs_copy['cs_count'] >= 1))
]

# %%
credit_suisse_articles.head()
# Out:
#                                         article_title  \
# 37  167 Jahre Credit Suisse: Das Ende einer Tradit...
# 53  UBS will offenbar mehr als die Hälfte der CS-B...
# 54  Auch andere Banken wollen wie die CS behandelt...
# 55  Nationalbank zieht die Lehren aus der UBS/CS-F...
# 56  UBS- und CS-Angestellte haben nun den gleichen...
#
#                                         merged_string  \
# 37  Am Anfang stand der Industrielle und Politiker...
# 53  Bei der von der UBS übernommenen Credit Suisse...
# 54  Der Credit Suisse Geld leihen, ohne dafür Sich...
# 55  Der schnelle Untergang der Credit Suisse im Mä...
# 56  Die UBS hat nach der Übernahme der Credit Suis...
#
#                    text_date  credit_suisse_count  cs_count
# 37 2023-03-19 19:22:00+00:00                    2         5
# 53 2023-06-27 16:14:00+00:00                    1         5
# 54 2023-06-24 15:15:00+00:00                    2         1
# 55 2023-06-22 07:59:00+00:00                    3         1
# 56 2023-06-19 13:08:00+00:00                    2         2

# %%
len(credit_suisse_articles)
# Out:
# 396

# %%
# Calculate the word count for each article in the credit_suisse_articles DataFrame
credit_suisse_articles.loc[:, 'word_count'] = credit_suisse_articles['merged_string'].str.split().apply(len)

# %%
# Sort the articles by date in ascending order
credit_suisse_articles_sorted = credit_suisse_articles.sort_values(by='text_date')

# %%
# rename merged_string column to article_content
credit_suisse_articles_sorted.columns
credit_suisse_articles_sorted.rename(columns={'merged_string': 'article_content'}, inplace=True)

# %%
# Export the sorted DataFrame to a CSV file
credit_suisse_articles_sorted.to_csv('Prepped_Data/CS_SRF_prepped.csv', index=False)

# %%
duplicate_indices_specific_columns = credit_suisse_articles_sorted[credit_suisse_articles_sorted.duplicated(subset=['text_date'], keep=False)].index
print("Indices of Duplicate Rows Based on Specific Columns:")
print(duplicate_indices_specific_columns)
# Out:
# Indices of Duplicate Rows Based on Specific Columns:
# Index([], dtype='int64')

# %% [markdown]
# ### UBS DATA PREP

# %%
# import SRF UBS data
file_path = "Data/SRF/scraped_data_UBS_april.csv"
df_srf_ubs = pd.read_csv(file_path)

# %%
df_srf_ubs.head()
# Out:
#                                        article_title  \
# 0  UBS und Käse: Guerreiro do Divino Amor spielt ...
# 1                      Die UBS muss sterblich werden
# 2             Welche Regeln braucht es für die UBS?
# 3  Wie gerecht sind die 14.4 Millionen Franken Lo...
# 4  UBS-Chef Ermotti verdient mehr als Vorgänger H...
#
#                                        merged_string  \
# 0  Guerreiro do Divino Amor – der Name ist portug...
# 1  Die Schweiz hat nur noch eine Grossbank. Wenn ...
# 2  Die Politik ist herausgefordert. Nach dem Deba...
# 3  14.4 Millionen Franken Entschädigung hat UBS-C...
# 4  Seit seiner Rückkehr zur UBS hat CEO Sergio Er...
#
#                    text_date
# 0  2024-04-19T08:24:00+02:00
# 1  2024-04-10T18:13:00+02:00
# 2  2024-04-10T14:31:00+02:00
# 3  2024-03-28T18:44:00+01:00
# 4  2024-03-28T07:55:00+01:00

# %%
len(df_srf_ubs)
# Out:
# 986

# %%
# Convert 'text_date' column to datetime type, considering timezone information
df_srf_ubs['text_date'] = pd.to_datetime(df_srf_ubs['text_date'], utc=True)

# Define the start and end dates of the desired range
start_date = pd.Timestamp('2019-01-01', tz='UTC')
end_date = pd.Timestamp('2023-06-30', tz='UTC')

# Filter the DataFrame to include only articles within the specified date range
filtered_df_srf_ubs = df_srf_ubs[(df_srf_ubs['text_date'] >= start_date) & (df_srf_ubs['text_date'] <= end_date)]

# %%
len(filtered_df_srf_ubs)
# Out:
# 310

# %%
# Create a copy of the filtered DataFrame
filtered_df_srf_ubs_copy = filtered_df_srf_ubs.copy()

# Count the occurrences of the phrases 'Credit Suisse' and 'CS' in each article's content in the copied DataFrame
def count_ubs(text):
    return len(re.findall(r'(?<![a-zA-Z])UBS(?![a-zA-Z])', text))
filtered_df_srf_ubs_copy['UBS_count'] = filtered_df_srf_ubs_copy['merged_string'].apply(count_ubs)

# Filter articles containing 'Credit Suisse' at least twice in their content
UBS_articles = filtered_df_srf_ubs_copy[filtered_df_srf_ubs_copy['UBS_count'] >= 2]

# %%
len(UBS_articles)
# Out:
# 234

# %%
# Calculate the word count for each article in the credit_suisse_articles DataFrame
#execute twice to make it work
UBS_articles.loc[:, 'word_count'] = UBS_articles['merged_string'].str.split().apply(len)

# %%
# Sort the articles by date in ascending order
UBS_articles_sorted = UBS_articles.sort_values(by='text_date')

# %%
# rename merged_string column to article_content
UBS_articles_sorted.columns
UBS_articles_sorted.rename(columns={'merged_string': 'article_content'}, inplace=True)

# %% [markdown]
# #### check for dups

# %%
# Assuming credit_suisse_articles_copy is your DataFrame
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns

display(UBS_articles_sorted)
# Out:
#                                          article_title  \
# 226        UBS-Datendieb zu 40 Monaten Haft verurteilt
# 225  UBS verdient im Schlussquartal weniger als erw...
# 224  Ein fragwürdiger UBS-Kredit mit gravierenden F...
# 223  «Die UBS muss sich fragen, ob sie ihre Pflicht...
# 483                            Der ungewollte Abschied
# 222                UBS muss 4.5 Milliarden Euro zahlen
# 221                            Ein Dämpfer für die UBS
# 220                   «Die UBS hat ein echtes Problem»
# 219          «Noch ist die Geschichte nicht bewältigt»
# 218  Hängige Milliardenbusse für UBS weckt neue Zwe...
# 217             Wer Mutter wird, bekommt weniger Bonus
# 216              Rückstellungen drücken auf UBS-Gewinn
# 695  «14 Millionen im internationalen Vergleich rel...
# 938      Banken stecken Milliarden in fossile Energien
# 686        Viel Ärger wegen fehlgeleiteter Überweisung
# 215  Schweizer Grossbanken buhlen um Chinas Superre...
# 214                    UBS mit deutlich weniger Gewinn
# 213  UBS-Pensionskasse kürzt Witwenrente um mehr al...
# 212  UBS-Aktionäre verweigern Entlastung der Untern...
# 210        UBS-Aktionäre stellen ihre Interessen voran
# 209                Bargeldbezüger zahlen bei UBS drauf
# 596     «Kleine Kunden sind für Banken nicht lukrativ»
# 593        Weko büsst Grossbanken wegen Devisenkartell
# 759     Proteste gegen Grossbanken in Zürich und Basel
# 438  Die europäischen Grossbanken hadern mit dem In...
# 772  Basler und Zürcher Klimaaktivisten wieder auf ...
# 207        Es braucht mehr Männer in den Frauenberufen
# 591           Schweizer Konzerne reduzieren Flugreisen
# 206           UBS wehrt sich gegen Klimasünder-Vorwurf
# 205                   UBS verdient mehr als im Vorjahr
# 204         UBS muss Kundendaten an Frankreich liefern
# 203  Folgenschwerer Entscheid für die UBS und den F...
# 700  «Parteien müssen die Unabhängigkeit der Richte...
# 202                Italien will an UBS-Kundendaten ran
# 478  Der Anfang vom Ende des Schweizer Bankgeheimni...
# 657    Finanzbranche hält die Türen für Lernende offen
# 201                Werden Hunderte Stellen gestrichen?
# 827                  Fall Khan: Was bisher bekannt ist
# 918      Wer nicht kuscht, muss mit Sanktionen rechnen
# 809                           Lohnt sich Sparen noch?
# 615   Credit Suisse führt Negativzinsen für Reiche ein
# 199    Wer ist der Platzhirsch am Bankenplatz Schweiz?
# 820  Hinter dem geplatzten UPC-Deal steht ein bekan...
# 198     Die Grossbanken wehren sich gegen ihre Zähmung
# 197  «Was die UBS heute angekündigt hat, ist kein g...
# 637  Störung beim E-Banking – stecken Hacker dahinter?
# 196  UBS erzielt Jahresgewinn von 4.3 Milliarden Do...
# 195   Die UBS forciert das Geschäftsmodell Klimaschutz
# 748  Traum vom Eigenheim rückt für viele in weite F...
# 194       Steht Sergio Ermotti kurz vor dem Rücktritt?
# 193            Ein Niederländer löst Sergio Ermotti ab
# 192  «Hamers hat grosse Erfahrung mit der Digitalis...
# 623          Grosse auf Kurs – Kleine hinken hinterher
# 597  Ermotti soll Verwaltungsratspräsident von Swis...
# 191   UBS hält versprochene Freigrenze nicht immer ein
# 763  Mehrere hundert Firmen beantragen grosse Notkr...
# 190                 Ex-UBS-Chef Marcel Ospel gestorben
# 466    Eine umstrittene Figur der Schweizer Wirtschaft
# 189  UBS erzielt trotz Coronakrise deutlich mehr Ge...
# 188             Die UBS sieht sich als Teil der Lösung
# 187  «Es wird für Banken und Wirtschaft bleibende V...
# 850               Coronakredite für KMU bleiben liegen
# 186  Positive Stimmung bei Unternehmen – aber nur o...
# 185  UBS erleidet Niederlage vor Bundesverwaltungsg...
# 184       UBS verdient weniger, aber mehr als erwartet
# 687        Die Krise könnte Reiche noch reicher machen
# 699             Viele Konzerne trotzen der Coronakrise
# 698             Viele Konzerne trotzen der Coronakrise
# 753  Solothurner Wirtschaft hat Talsohle durchschri...
# 697                             Die Bank gewinnt immer
# 633   Banker ohne Krawatten – das sagt die Modebranche
# 183   Medienberichte: UBS und CS  sollen Fusion planen
# 477  100 Franken Zuschlag für eine Einzahlung am Sc...
# 960  Berichte: Grossbanken betreiben weiter Milliar...
# 182  Sergio Ermotti: «Immer nur gemacht, was mich e...
# 181         Vier Wochen Vaterschaftsurlaub bei der UBS
# 882        Der Immobilienmarkt in Zürich ist überhitzt
# 457       Der Schweizer Finanzplatz und die Klimakrise
# 180  UBS verdoppelt Gewinn – Wochenlohn als Geschen...
# 179  Abschied im Guten – Stabilisator Sergio Ermott...
# 178  Die wichtigsten Fragen und Antworten zum neuen...
# 614  Geheimdienstaffäre: Weitere Schweizer Firma rü...
# 177    Sabine Keller-Busse wird Chefin der UBS Schweiz
# 176  UBS-Chef Ralph Hamers im Visier von niederländ...
# 175        UBS plant Schliessung jeder fünften Filiale
# 174  Filialschliessungen: Den Banken muss ein Spaga...
# 600     Bedingungsloser Freispruch für Klimaaktivisten
# 173  UBS-Chef Ralph Hamers und die Schatten der Ver...
# 172             UBS kann Gewinn 2020 deutlich steigern
# 171  UBS-Chef Hamers tut das Einzige, was er tun ka...
# 170  «Ich habe volles Vertrauen in einen guten Ausg...
# 917  Wie Ikea, Postfinance & Co. zu Versicherungsan...
# 169      So viel verdienten die UBS-Chefs im Jahr 2020
# 168         Die UBS hofft in Paris auf gnädige Richter
# 790               Schweizer Wirtschaft ist zweigeteilt
# 846                  Corona krempelt den Kunstmarkt um
# 670  Finma stellt grossen Banken gutes Zeugnis zu N...
# 167  Steuerbetrug: Punktsieg für die UBS – Milliard...
# 671  Credit Suisse sollte ihr Geschäftsmodell überd...
# 612  Bankenplatz Schweiz verliert international an ...
# 166   UBS: Archegos-Pleite überschattet gutes Ergebnis
# 165  Marcel Rohner wird neuer Präsident der Bankier...
# 816  SNB bekräftigt: «Too-Big-to-Fail»-Regime ist n...
# 164  UBS verdient im zweiten Quartal über 2 Milliar...
# 163                      Die UBS macht eine gute Figur
# 613       Schweiz boomt als Tummelplatz für Millionäre
# 162  CS ist mit sich beschäftigt – Konkurrentin UBS...
# 606  Mehr als 80 Klimaaktivisten vorläufig festgeno...
# 161          Credit Suisse holt sich Ex-UBS-Topmanager
# 476          Das sind die wettbewerbsfähigsten Kantone
# 160             UBS verdient erneut über 2 Milliarden
# 159  Löhne in der Schweiz steigen im nächsten Jahr ...
# 158  Colm Kelleher als neuer Präsident der UBS vorg...
# 157    UBS ernennt erstmals eine Frau zur Finanzchefin
# 156  Frankreich: Gericht bestätigt UBS-Urteil – Str...
# 155  UBS zieht Urteil im Steuerstreit mit Frankreic...
# 154  Die UBS ist unbeugsam – das dürfte sich vorläu...
# 153         UBS erzielt bestes Ergebnis seit 15 Jahren
# 152            UBS steht mit Digitalisierung am Anfang
# 151  UBS-CEO Ralph Hamers kassierte 2021  11.5 Mill...
# 150  Credit-Suisse-Chef bekommt deutlich weniger Lo...
# 149  UBS-Aktionäre wählen Colm Kelleher zum neuen P...
# 148  Axel Weber: «Wir halten uns an alle Sanktionen...
# 680  Warum der Libanon kollabiert: der Fall Riad Sa...
# 808  Gekaufte Forschung – das Ende der akademischen...
# 147  Trotz Ukraine-Krieg: UBS steigert Gewinn deutl...
# 146  Worum es beim Kreditgeschäft der UBS in Papua ...
# 556  Staatshilfe in der Krise: ein lohnendes «Gesch...
# 145  UBS zahlt 25 Millionen Dollar für Vergleich im...
# 144          UBS verfehlt trotz Gewinnplus Erwartungen
# 143  «Die UBS arbeitet derzeit sicher nicht im Kris...
# 142           UBS bezahlt der ETH 40 Millionen Franken
# 607  Bund schlüpft – einmal mehr – in die Rolle ein...
# 141  UBS und CS bezahlen je 125 Millionen Dollar St...
# 875   Trübe Aussichten für Nationalbank-Ausschüttungen
# 140    UBS übertrifft Erwartungen trotz Gewinnrückgang
# 139  Staatsanwaltschaft untersucht deutsche UBS-Fil...
# 747                Inflation frisst Lohnerhöhungen auf
# 138  Beseitigung der AHV-Lücke führt laut UBS über ...
# 136  UBS will «Lower Risk»-Strategie in USA fortsetzen
# 691  Indischer Milliardär verliert über 100 Milliar...
# 135   12.6 Millionen Franken für UBS-Chef Ralph Hamers
# 536  Fall CS: Politiker fordern Transparenz über SN...
# 134  Medienberichte: UBS führt Übernahme-Gespräche ...
# 133  Gespräche zwischen UBS und CS? Die wichtigsten...
# 132  UBS und CS: Zwei unterschiedliche Bankenschwer...
# 806  Reto Lipp: «Es zeichnet sich ein Erdbeben auf ...
# 685  Credit Suisse: Die Ereignisse der letzten Tage...
# 131  UBS übernimmt Credit Suisse: Die wichtigsten P...
# 41   167 Jahre Credit Suisse: Das Ende einer Tradit...
# 130          Zwangsheirat unter schwierigen Vorzeichen
# 129  UBS-CEO: «Zusammen können wir eine noch schöne...
# 128  Parteispitzen: Bank-Management muss Verantwort...
# 127           Die Reaktionen auf die CS-Rettungsaktion
# 126  UBS übernimmt: Was bedeutet das für mein CS-Ko...
# 125  Was passiert mit meinem Geld, der Hypothek und...
# 124  «Wehmut kommt auf»: Katerstimmung bei CS-Kunde...
# 122  Neuer Bankenkoloss: Hat der Bundesrat ein «Mon...
# 514                     Wie weiter mit der Giga-Bank?
# 120  Grosse Kulturhäuser bangen um Sponsoring-Gelde...
# 119  «Alles andere als eine überzeugende Arbeit der...
# 118  «Es räblet»: CS-Kunden wechseln zu Regionalbanken
# 116  Ex-Finma-Experte: Jahrelanges Kaderversagen so...
# 518  Hamers und Kelleher: Wer sind die neuen Chefs ...
# 732  CS-Gläubiger verlieren Milliarden – ist ihre E...
# 115  Bankenpräsident: «Alternative wäre die Abwickl...
# 114  Kommt das geplante Zürcher Fussballstadion nun...
# 513            Was ist mit der Credit Suisse passiert?
# 113   Nächster Schritt: UBS-Boni unter die Lupe nehmen
# 801  Bund stoppt Auszahlung gewisser CS-Boni – das ...
# 112  Hat das Ausland die Übernahme der CS durch die...
# 788  SVP und FDP geben sich gegenseitig Schuld am C...
# 681  Forderungen nach einem Trennbanksystem werden ...
# 111  Aymo Brunetti: «Eine schweizerische Einheit de...
# 108  Übernahme der CS muss doch die Wettbewerbsprüf...
# 646  Das hält das Schweizer Stimmvolk von der Übern...
# 794        Die «beste Lösung» für die CS weckt Skepsis
# 720  Riskante AT1-Anleihen: Antworten zum 17-Millia...
# 789  US-Botschafter in Bern: «Wiederausfuhr-Verbot ...
# 689  Keller-Sutter: «Risiken für die Steuerzahler k...
# 105     Colm Kelleher – mächtigster Banker der Schweiz
# 103  Von Abspaltung bis Schweizer Quote: Das forder...
# 539  Finma im Rampenlicht – viele offene Fragen zur...
# 101  FDP-Vorstoss zur Abspaltung der CS Schweiz geh...
# 99   Sergio Ermotti kehrt als Konzernchef der UBS z...
# 98      Darum setzt die UBS wieder auf Ermotti als CEO
# 97   Der richtige Mann für den schwierigsten Job de...
# 719  Wirtschaftsethiker: «Wir sind dem Finanzsystem...
# 96          Finma-Chef: «Wir müssen sehr wachsam sein»
# 725  So viel verdient der Bund an den Garantien für...
# 94           Ein neuer Gigant auf dem Immobilienmarkt?
# 93   So ist das 259 Milliarden Franken dicke Sicher...
# 775  Parteispitzen sind sich einig: CS-Kader sollen...
# 577        Letzte CS-Generalversammlung: Darum geht es
# 804  «An diesem Montag hätte es wohl eine Finanzkri...
# 92              UBS-Generalversammlung: Darum geht es
# 91   Aktionärsdemokratie – ein Wort für den Müllhau...
# 752   Nach CS-Debakel: Darum kommuniziert die Finma...
# 869  Bund hat Risiken für Steuerzahlende zu wenig k...
# 90   Fusionsexperte zur neuen UBS: «Das Risiko ist ...
# 768  Leere Drohungen der Parteien im Fall Credit Su...
# 782                      Ein denkwürdiger Tag in Bern
# 668                      Das Parlament im Protestmodus
# 868  Banker: «Hört auf mit dem Boniverbot, es bring...
# 87   Ablehnung der CS-Kredite – politischer Streit ...
# 86   So begründet der Gesamtbundesrat die Hilfe bei...
# 85   Bund und UBS haben keine schriftliche Verpflic...
# 84   Was ist die mündliche Vereinbarung zwischen Bu...
# 82   Ist die 9-Milliarden-Garantie für die UBS gült...
# 80   Credit Suisse weist Geldabflüsse von 61 Millia...
# 79   Die Patientin Credit Suisse liegt nach wie vor...
# 728  Keller-Sutter: «Es wurden bis zu 80 Milliarden...
# 78   UBS startet mit 1.03 Milliarden Dollar Gewinn ...
# 77               UBS hält sich bedeckt zur CS-Zukunft
# 76   Sergio Ermotti: «Nachhaltigkeit ist ebenso wic...
# 75         Der Weg zur erfolgreichen Megabank ist weit
# 658  Finma: Notfallpläne von Postfinance und ZKB no...
# 74   «Systemrelevante Banken abzuschaffen, ist ein ...
# 73   Roman Studer neuer Geschäftsführer der Bankier...
# 724  Auszahlung von «gesicherten» CS-Einlagen würde...
# 72   CS-Chef Körner leitet UBS mit – Banken operier...
# 71    Nach dem Feuerwehreinsatz folgt der Wiederaufbau
# 70   Die neue Superbank – eine Hypothek für die Sch...
# 69    UBS wird dank CS-Übernahme Rekordgewinn erzielen
# 543               Ferienwohnungen werden kaum billiger
# 68   Bund und UBS regeln 9-Milliarden-Verlustgarant...
# 67   Bund und UBS unterzeichnen Vertrag zu Verlustg...
# 66   UBS-Chef Ermotti begrüsst PUK zur Rettung der ...
# 601  Die Credit Suisse ist offiziell Geschichte – w...
# 599            Besser nur eine Grossbank, aber richtig
# 751          Wo einst der Henker von Zürich residierte
# 65         Besuch uns diesen Sommer am «UBS Kids Cup»!
# 64   UBS- und CS-Angestellte haben nun den gleichen...
# 62   UBS will offenbar mehr als die Hälfte der CS-B...
#
#                                        article_content  \
# 226  Das Bundesstrafgericht hat einen Ex-UBS-Mitarb...
# 225  Die UBS hat im vierten Quartal 2018 die Erwart...
# 224  Als Peter O’Neill 2011 in Papua-Neuguinea an d...
# 223  In Papua-Neuguinea hat ein fragwürdiger Kredit...
# 483  Eine Viertelstunde vor Mitternacht lässt die U...
# 222  Im Prozess am Pariser Strafgerichtshof gegen d...
# 221  Das Gericht ist dem Strafantrag der Staatsanwä...
# 220  Sowohl die UBS-Banker wie auch deren Anwälte h...
# 219  Nach der Verurteilung der UBS in Frankreich zu...
# 218  Im Licht des jüngsten Gerichtsentscheides gege...
# 217  Die UBS rühmt sich bei jeder Gelegenheit, ein ...
# 216  Der Reingewinn von 4.5 Milliarden Dollar bedeu...
# 695  UBS-Chef Sergio Ermotti hat im letzten Jahr ru...
# 938  Seit dem Klimabekenntnis von Paris 2016 stellt...
# 686  Das Wichtigste in Kürze: Wer beim E-Banking mi...
# 215  Trotz Menschenrechtsverletzungen ist China int...
# 214  Die UBS hat im ersten Quartal 2019 deutlich we...
# 213  Laut Gesetz beträgt eine Witwenrente 60 Prozen...
# 212  Die UBS-Aktionäre haben an der Generalversamml...
# 210  Die UBS-Leitung hat es an der heutigen General...
# 209  Die UBS will eigenen Bankkunden ab 1. Juli für...
# 596  Die UBS wird ihren Bankkunden ab 1. Juli für j...
# 593  Wegen eines Devisenkartells müssen die gebüsst...
# 759  Klimaaktivisten haben am Montagmorgen in Züric...
# 438  Aus dem globalen Aktienhandel will die Deutsch...
# 96  2023-03-29 17:35:00+00:00          7         578
# 725 2023-03-30 02:01:00+00:00          3         334
# 94  2023-03-31 12:43:00+00:00          8         400
# 93  2023-03-31 13:54:00+00:00          5         455
# 775 2023-03-31 21:13:00+00:00          5         534
# 577 2023-04-04 02:55:00+00:00          2         304
# 804 2023-04-04 04:27:00+00:00          3         503
# 92  2023-04-05 02:11:00+00:00          7         403
# 91  2023-04-05 14:08:00+00:00          2         452
# 752 2023-04-05 15:24:00+00:00          2         451
# 869 2023-04-06 14:01:00+00:00          2         578
# 90  2023-04-10 09:14:00+00:00          6         494
# 768 2023-04-11 13:26:00+00:00          2         423
# 782 2023-04-11 21:28:00+00:00          3         460
# 668 2023-04-12 13:25:00+00:00          6         450
# 868 2023-04-14 21:01:00+00:00          3         513
# 87  2023-04-15 13:25:00+00:00          5         511
# 86  2023-04-19 17:14:00+00:00          6         428
# 85  2023-04-21 02:03:00+00:00          6         347
# 84  2023-04-21 07:28:00+00:00          7         349
# 82  2023-04-21 16:58:00+00:00          4         362
# 80  2023-04-24 02:55:00+00:00          7         292
# 79  2023-04-24 06:32:00+00:00          5         286
# 728 2023-04-24 15:32:00+00:00          4         521
# 78  2023-04-25 02:53:00+00:00          7         388
# 77  2023-04-25 06:38:00+00:00          9         388
# 76  2023-04-25 12:26:00+00:00          6         571
# 75  2023-04-25 14:57:00+00:00         11         454
# 658 2023-04-26 07:17:00+00:00          3         249
# 74  2023-04-29 11:28:00+00:00          2         480
# 73  2023-05-03 14:20:00+00:00          6         335
# 724 2023-05-03 15:40:00+00:00          2         446
# 72  2023-05-09 03:11:00+00:00         19         441
# 71  2023-05-09 07:55:00+00:00          5         369
# 70  2023-05-12 16:01:00+00:00          5         428
# 69  2023-05-17 06:35:00+00:00         11         500
# 543 2023-05-26 18:32:00+00:00          3         472
# 68  2023-06-05 04:19:00+00:00          6         170
# 67  2023-06-09 06:06:00+00:00         11         365
# 66  2023-06-09 09:40:00+00:00          7         355
# 601 2023-06-12 12:21:00+00:00         12         522
# 599 2023-06-12 17:34:00+00:00         10         421
# 751 2023-06-13 09:59:00+00:00          8         514
# 65  2023-06-15 13:12:00+00:00          2         158
# 64  2023-06-19 13:08:00+00:00          4         220
# 62  2023-06-27 16:14:00+00:00          8         267

# %%
duplicate_indices_specific_columns = UBS_articles_sorted[UBS_articles_sorted.duplicated(subset=['article_content'], keep=False)].index
print("Indices of Duplicate Rows Based on Specific Columns:")
print(duplicate_indices_specific_columns)
# Out:
# Indices of Duplicate Rows Based on Specific Columns:
# Index([699, 698], dtype='int64')

# %%
UBS_articles_sorted.loc[698, "article_title"]
# Out:
# 'Viele Konzerne trotzen der Coronakrise'

# %%
len(UBS_articles_sorted)
# Out:
# 234

# %%
# Remove duplicate rows based on specific columns
UBS_articles_no_dups = UBS_articles_sorted.drop_duplicates(subset=['article_content'], keep='first')

# %%
len(UBS_articles_no_dups)
# Out:
# 233

# %%
# Export the sorted DataFrame to a CSV file
UBS_articles_no_dups.to_csv('Prepped_Data/UBS_SRF_prepped.csv', index=False)
